# %%
import numpy as np
from scipy.stats import t
import matplotlib.pyplot as plt

# Define the degrees of freedom
df_values = [1, 2, 5, 10]

# Create separate plots for each degree of freedom
for df in df_values:
    # Generate values of x
    x = np.linspace(-5, 5, 100)

    # Calculate the PDF of the t-distribution
    pdf = t.pdf(x, df)

    # Plot the PDF curve
    plt.plot(x, pdf, label=f'df={df}')

# Add labels and a legend to the plot
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.title('t-Distribution with Different Degrees of Freedom')
plt.legend()

# Show the plot
plt.show()

# %%
import seaborn as sns

# Degrees of freedom values
df_values = [1, 2, 5, 10]

# Define a list of colors for gradual change
colors = ['blue', 'green', 'orange', 'red']

# Create separate plots for each degree of freedom
for i, df in enumerate(df_values):
    x = np.linspace(0, 20, 100)
    y = chi2.pdf(x, df)

    # Plot the chi-squared distribution for each degree of freedom with gradual colors
    sns.lineplot(x, y, label=f'df={df}', color=colors[i])

    # Label the lines on the chart
    max_y = np.max(y)
    max_x = x[np.argmax(y)]
    plt.text(max_x, max_y, f'df={df}', ha='right', va='bottom')

# Add a legend to the combined plot
plt.legend()

# Set the title, x-axis label, and y-axis label
plt.title('Chi-squared Distributions for Different Degrees of Freedom')
plt.xlabel('X')
plt.ylabel('Probability Density Function')

# Show the combined plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/yohkawano/Library/CloudStorage/GoogleDrive-ykawano@reitaku-u.ac.jp/My Drive/Classroom/2023 2nd Semester/23-2-Reitaku-Stats-B/Week09/w9.ipynb Cell 2 line 1
#      <a href='vscode-notebook-cell:/Users/yohkawano/Library/CloudStorage/GoogleDrive-ykawano%40reitaku-u.ac.jp/My%20Drive/Classroom/2023%202nd%20Semester/23-2-Reitaku-Stats-B/Week09/w9.ipynb#W1sZmlsZQ%3D%3D?line=11'>12</a> y = chi2.pdf(x, df)
#      <a href='vscode-notebook-cell:/Users/yohkawano/Library/CloudStorage/GoogleDrive-ykawano%40reitaku-u.ac.jp/My%20Drive/Classroom/2023%202nd%20Semester/23-2-Reitaku-Stats-B/Week09/w9.ipynb#W1sZmlsZQ%3D%3D?line=13'>14</a> # Plot the chi-squared distribution for each degree of freedom with gradual colors
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

# Degrees of freedom values
df_values = [1, 2, 5, 10]

# Create separate plots for each degree of freedom
for i, df in enumerate(df_values):
    x = np.linspace(0, 20, 100)
    y = chi2.pdf(x, df)

    # Create a new figure for each plot
    plt.figure(i+1)

    # Plot the chi-squared distribution
    plt.plot(x, y)
    plt.title(f'Chi-squared Distribution for df={df}')
    plt.xlabel('X')
    plt.ylabel('Probability Density Function')

# Show all the plots
plt.show()




# Create separate plots for each degree of freedom
for df in df_values:
    x = np.linspace(0, 20, 100)
    y = chi2.pdf(x, df)

    # Plot the chi-squared distribution for each degree of freedom
    plt.plot(x, y, label=f'df={df}')
    plt.title('Chi-squared Distributions for Different Degrees of Freedom')
    plt.xlabel('X')
    plt.ylabel('Probability Density Function')

# Add a legend to the combined plot
plt.legend()

# Show the combined plot
plt.show()
